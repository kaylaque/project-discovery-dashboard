# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('team_lists_all_years.csv', lineterminator='\n')
df.head()
# Out:
#         Team name                               Profile team  \
# 0    Alberta_NINT  https://old.igem.org/Team.cgi?team_id=102
# 1    Bay_Area_RSI   https://old.igem.org/Team.cgi?team_id=80
# 2    BCCS-Bristol  https://old.igem.org/Team.cgi?team_id=135
# 3  Beijing_Normal   https://old.igem.org/Team.cgi?team_id=78
# 4         Bologna   https://old.igem.org/Team.cgi?team_id=79
#
#                                     Wiki URL         Region         Country  \
# 0    https://2008.igem.org/Team:Alberta_NINT  North America          Canada
# 1    https://2008.igem.org/Team:Bay_Area_RSI  North America   United States
# 2    https://2008.igem.org/Team:BCCS-Bristol         Europe  United Kingdom
# 3  https://2008.igem.org/Team:Beijing_Normal           Asia           China
# 4         https://2008.igem.org/Team:Bologna         Europe           Italy
#
#   Track        Kind Section Application  Year                   Title  \
# ...
